# %%
import numpy as np
import pandas as pd
import igraph
import random as rnd
import csv

# %%
class NS:

    # 初始化
    def __init__(self, num_nodes, p_rewire, z, a, mod, end_ratio, echo):
        self.num_nodes = num_nodes
        self.p_rewire = p_rewire
        self.z = z
        self.a = a
        self.mod = mod
        self.end_ratio = end_ratio
        self.echo = echo

        # 1. create the network
        # create a small world without randomness
        g = igraph.Graph.Watts_Strogatz(dim = 1,
            size = self.num_nodes,
            nei = int(z/2),
            p = 0)
        # Randomly rewires the graph while preserving the degree distribution
        g.rewire(n = int(g.ecount() * 0.5 * self.p_rewire),
            mode = "simple")

        # 2. set up states
        # the initial node and its neighbors are activited
        focal_node = rnd.sample(range(self.num_nodes), 1)[0]
        initial_activate = g.neighborhood(vertices=focal_node,
            order = 1)
        self.State = np.zeros(shape = (self.num_nodes,))
        self.State[initial_activate, ] = 1


        # 3. weight matrix
        adj_matrix = g.get_adjacency_sparse() # get adjacency matrix
        # mode1
        if mod == 1:
            self.WM = adj_matrix[:,:]
        # mode2 and mode3
        else:
            # calculate edge betweeness
            Centrality = np.array(g.edge_betweenness())
            cut_points = np.percentile(Centrality, q=[25, 75])

            # change the value based on cut_points
            Centrality[Centrality < cut_points[0]] = 1  # ties embedded in small circle
            Centrality[(Centrality >= cut_points[0]) & (Centrality < cut_points[1])] = 2
            Centrality[Centrality >= cut_points[1]] = 3 # long-range ties
            # mode2
            if mod == 2:
                self.WM = adj_matrix[:,:]
                # get index of strong ties
                id_strong_mod2 = np.where(Centrality == 1)[0]
                # change the matrix
                for source_target in g.es[list(id_strong_mod2)]:
                    i, j = source_target.tuple
                    self.WM[i, j] = 5
                    self.WM[j, i] = 5
            # mode3
            else:
                self.WM = adj_matrix[:,:]
                # get index of strong ties
                id_strong_embed = np.random.choice(np.where(Centrality == 1)[0], 
                    int(g.ecount() * .2), replace=False)
                id_strong_long_range = np.random.choice(np.where(Centrality == 3)[0], 
                    int(g.ecount() * .05), replace=False)
                id_strong_mod3 = np.hstack((id_strong_embed, id_strong_long_range))
                # chang the matrix
                for source_target in g.es[list(id_strong_mod3)]:
                    i, j = source_target.tuple
                    self.WM[i, j] = 5
                    self.WM[j, i] = 5
    
    # 模拟函数
    def start_contagion(self):

        times = 0 # record steps
        prop_path = [self.State.mean()] # record proportions
        f = open("sim_record.csv", mode = 'a', newline='')
        csv_writer = csv.writer(f)

        # contagion process
        while prop_path[-1] <= self.end_ratio:

            # nonactivated nodes index:
            nonactivated_index = np.where(self.State != 1)[0]

            # update these nonactivated nodes in random order
            np.random.shuffle(nonactivated_index)
            for i in nonactivated_index:
                total_effects = np.dot(self.State, self.WM[:, i].toarray())[0]
                if total_effects >= self.a:
                    self.State[i] = 1
            
            # recording after one-step iteration
            times += 1
            prop_path.append(self.State.mean())

            # print this step 
            if self.echo:
                print('第{}次迭代后:  {}的节点被激活'.format(times, prop_path[-1]))
            
            # stop the contagion if necessary
            if prop_path[-1] == prop_path[-2]:
                times = 9999
                csv_writer.writerow([self.mod, self.num_nodes, self.z, self.a, self.p_rewire, times])
                break

        else:
            # write csv
            csv_writer.writerow([self.mod, self.num_nodes, self.z, self.a, self.p_rewire, times])
            print('**模式{}:N={},z={}, a={}, p_rewire={}, 时长{}'.format(self.mod, self.num_nodes, self.z, self.a, self.p_rewire, times))

        f.close()

# %%
# 定义参数空间
p_rewire_vector = np.power(10, np.arange(-3, 0.1, .1)) # p_rewire   
a_vector =  [1, 2, 3]
mod_vector =  [1, 2, 3]
Repeat_time =  100 # 每个参数组合重复多少次

# 总次数
total_iters = p_rewire_vector.shape[0] * len(a_vector) * len(mod_vector) * Repeat_time 
# 计数器
count_iter = 0

# 循环
for mod in mod_vector:
    for a in a_vector:
        for p_rewire in p_rewire_vector:
            for i in range(Repeat_time):
                network_simulation = NS(num_nodes = 2000, 
                    p_rewire = p_rewire, 
                    z = 12, 
                    a = a, 
                    mod = mod, 
                    end_ratio = .99, 
                    echo = False)
                network_simulation.start_contagion()
                count_iter += 1
                print('{}/{}'.format(count_iter, total_iters))
# Out:
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 1/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 2/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 3/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长25
# 4/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 5/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 6/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 7/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 8/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 9/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 10/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 11/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 12/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长27
# 13/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 14/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 15/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长15
# 16/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 17/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 18/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 19/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 20/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 21/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 22/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长28
# 23/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长27
# 24/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长27
# 25/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长30
# 26/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 27/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 28/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 29/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 30/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 31/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 32/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长27
# 33/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 34/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长15
# 35/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长22
# 36/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 37/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 38/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 39/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 40/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 41/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 42/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长13
# 43/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 44/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 45/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长22
# 46/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 47/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 48/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 49/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 50/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长13
# 51/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 52/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 53/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长15
# 54/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 55/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长26
# 56/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长25
# 57/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 58/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长26
# 59/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 60/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 61/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长25
# 62/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长22
# 63/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 64/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长25
# 65/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长13
# 66/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长22
# 67/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 68/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 69/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长32
# 70/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 71/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长15
# 72/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 73/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长13
# 74/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 75/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 76/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 77/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 78/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 79/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 80/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 81/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 82/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长17
# 83/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 84/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长29
# 85/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 86/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长24
# 87/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 88/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长22
# 89/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长14
# 90/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长20
# 91/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 92/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 93/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长21
# 94/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长23
# 95/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 96/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 97/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长16
# 98/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长18
# 99/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001, 时长19
# 100/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 101/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 102/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 103/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长26
# 104/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 105/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 106/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 107/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 108/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 109/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 110/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 111/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 112/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 113/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 114/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 115/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 116/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 117/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 118/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 119/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 120/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 121/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 122/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长22
# 123/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 124/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 125/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 126/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 127/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 128/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 129/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 130/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长23
# 131/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 132/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长23
# 133/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长14
# 134/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长23
# 135/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 136/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 137/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长14
# 138/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 139/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 140/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 141/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 142/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 143/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 144/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长23
# 145/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 146/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 147/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 148/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 149/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 150/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 151/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 152/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 153/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 154/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 155/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 156/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 157/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长25
# 158/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长30
# 159/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长26
# 160/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 161/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 162/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长24
# 163/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长22
# 164/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 165/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 166/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 167/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 168/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 169/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长14
# 170/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 171/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长25
# 172/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 173/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长26
# 174/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长22
# 175/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长14
# 176/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 177/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 178/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 179/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 180/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 181/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 182/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长21
# 183/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 184/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长13
# 185/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 186/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 187/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长22
# 188/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 189/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 190/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 191/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长17
# 192/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长20
# 193/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 194/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长18
# 195/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长19
# 196/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 197/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长15
# 198/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长12
# 199/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.0012589254117941675, 时长16
# 200/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 201/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长14
# 202/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长14
# 203/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长13
# 204/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 205/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 206/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 207/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长19
# 208/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 209/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长19
# 210/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长21
# 211/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 212/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 213/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长21
# 214/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长14
# 215/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 216/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 217/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长20
# 218/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长18
# 219/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 220/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长13
# 221/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 222/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长20
# 223/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 224/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 225/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长12
# 226/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 227/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 228/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长18
# 229/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长14
# 230/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 231/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 232/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 233/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长14
# 234/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长13
# 235/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长17
# 236/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长10
# 237/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长16
# 238/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 239/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长20
# 240/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
# 241/27900
# **模式1:N=2000,z=12, a=1, p_rewire=0.001584893192461114, 时长15
#